# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt

# Load data
df = pd.read_csv("../data/cleaned_data.csv")

st.title("Global Economic Intelligence Dashboard")

# Country selector
country = st.selectbox("Select Country", df["Country"].unique())

# Filter data
data = df[df["Country"] == country]
data = data.groupby("Year")["GDP_USD"].mean().reset_index()
data = data.sort_values("Year")

# Plot chart
fig, ax = plt.subplots()

ax.plot(data["Year"], data["GDP_USD"]/1e12, marker="o")

ax.set_title("GDP Trend - " + country)
ax.set_xlabel("Year")
ax.set_ylabel("GDP (Trillion USD)")

st.pyplot(fig)
# Out:
# 2026-03-11 17:06:38.711 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-11 17:06:38.988
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/lib/python3.14/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-03-11 17:06:38.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-11 17:06:38.990 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-11 17:06:39.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-11 17:06:39.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-11 17:06:39.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-11 17:06:39.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-11 17:06:39.162 Session state does not function when running a script without `streamlit run`
# 2026-03-11 17:06:39.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-11 17:06:39.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-11 17:06:39.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-11 17:06:39.585 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-11 17:06:40.037 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-11 17:06:40.038 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-11 17:06:40.038 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
